# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mplt
import numpy as np

# %%
data = pd.read_csv('data/properatti.csv')

# %%
pd.set_option('display.max_columns',1000000)

# %%
data
# Out:
#         Unnamed: 0 operation property_type       place_name  \
# 0                0      sell            PH        Mataderos
# 1                1      sell     apartment         La Plata
# 2                2      sell     apartment        Mataderos
# 3                3      sell            PH          Liniers
# 4                4      sell     apartment           Centro
# ...            ...       ...           ...              ...
# 121215      121215      sell     apartment         Belgrano
# 121216      121216      sell         house           Beccar
# 121217      121217      sell     apartment    Villa Urquiza
# 121218      121218      sell     apartment      Plaza Colón
# 121219      121219      sell     apartment  Capital Federal
#
#                                   place_with_parent_names country_name  \
# 0                   |Argentina|Capital Federal|Mataderos|    Argentina
# 1             |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121220 entries, 0 to 121219
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Unnamed: 0                  121220 non-null  int64
#  1   operation                   121220 non-null  object
#  2   property_type               121220 non-null  object
#  3   place_name                  121197 non-null  object
#  4   place_with_parent_names     121220 non-null  object
#  5   country_name                121220 non-null  object
#  6   state_name                  121220 non-null  object
#  7   geonames_id                 102503 non-null  float64
#  8   lat-lon                     69670 non-null   object
#  9   lat                         69670 non-null   float64
#  10  lon                         69670 non-null   float64
#  11  price                       100810 non-null  float64
# ...

# %%
data.columns[data.isna().any()].tolist()
# Out:
# ['place_name',
#  'geonames_id',
#  'lat-lon',
#  'lat',
#  'lon',
#  'price',
#  'currency',
#  'price_aprox_local_currency',
#  'price_aprox_usd',
#  'surface_total_in_m2',
#  'surface_covered_in_m2',
#  'price_usd_per_m2',
#  'price_per_m2',
#  'floor',
#  'rooms',
#  'expenses',
#  'description',
#  'image_thumbnail']

# %%
data["currency"].value_counts()
# Out:
# USD    87587
# ARS    13219
# PEN        2
# UYU        1
# Name: currency, dtype: int64

# %%
subset= data[["price","currency","price_aprox_local_currency","price_aprox_usd"]]

# %%
subset
# Out:
#            price currency  price_aprox_local_currency  price_aprox_usd
# 0        62000.0      USD                  1093959.00          62000.0
# 1       150000.0      USD                  2646675.00         150000.0
# 2        72000.0      USD                  1270404.00          72000.0
# 3        95000.0      USD                  1676227.50          95000.0
# 4        64000.0      USD                  1129248.00          64000.0
# ...          ...      ...                         ...              ...
# 121215  870000.0      USD                 15350715.00         870000.0
# 121216  498000.0      USD                  8786961.00         498000.0
# 121217  131500.0      USD                  2320251.75         131500.0
# 121218   95900.0      USD                  1692107.55          95900.0
# 121219  129000.0      USD                  2276140.50         129000.0
#
# [121220 rows x 4 columns]

# %%
subset["price"].isna().sum()
# Out:
# 20410

# %%
subset["currency"].isna().sum()
# Out:
# 20411

# %%
subset["price_aprox_local_currency"].isna().sum()
# Out:
# 20410

# %%
subset[subset.currency.isna()]
# Out:
#         price currency  price_aprox_local_currency  price_aprox_usd
# 5         NaN      NaN                         NaN              NaN
# 20        NaN      NaN                         NaN              NaN
# 41        NaN      NaN                         NaN              NaN
# 62        NaN      NaN                         NaN              NaN
# 67        NaN      NaN                         NaN              NaN
# ...       ...      ...                         ...              ...
# 121210    NaN      NaN                         NaN              NaN
# 121211    NaN      NaN                         NaN              NaN
# 121212    NaN      NaN                         NaN              NaN
# 121213    NaN      NaN                         NaN              NaN
# 121214    NaN      NaN                         NaN              NaN
#
# [20411 rows x 4 columns]

# %%
data[data.currency.isna()].head(5)
# Out:
#     Unnamed: 0 operation property_type        place_name  \
# 5            5      sell         house      Gualeguaychú
# 20          20      sell         house    Villa Giardino
# 41          41      sell     apartment  Villa Carlos Paz
# 62          62      sell         house       Berazategui
# 67          67      sell         house         Ituzaingó
#
#                            place_with_parent_names country_name  \
# 5              |Argentina|Entre Ríos|Gualeguaychú|    Argentina
# 20              |Argentina|Córdoba|Villa Giardino|    Argentina
# 41            |Argentina|Córdoba|Villa Carlos Paz|    Argentina
# 62  |Argentina|Bs.As. G.B.A. Zona Sur|Berazategui|    Argentina
# 67  |Argentina|Bs.As. G.B.A. Zona Oeste|Ituzaingó|    Argentina
#
#                   state_name  geonames_id                  lat-lon        lat  \
# 5                 Entre Ríos    3433657.0   -33.0140714,-58.519828 -33.014071
# ...

# %%
data[data.currency.isna()][["price_usd_per_m2","surface_covered_in_m2","surface_total_in_m2"]]
# Out:
#         price_usd_per_m2  surface_covered_in_m2  surface_total_in_m2
# 5                    NaN                    NaN                 53.0
# 20                   NaN                  148.0                148.0
# 41                   NaN                  115.0                115.0
# 62                   NaN                  156.0                156.0
# 67                   NaN                    NaN                220.0
# ...                  ...                    ...                  ...
# 121210               NaN                  120.0                  NaN
# 121211               NaN                  205.0                205.0
# 121212               NaN                  420.0                420.0
# 121213               NaN                  600.0                600.0
# 121214               NaN                  123.0                123.0
#
# [20411 rows x 3 columns]

# %%
data[data.currency.isna()]["price_usd_per_m2"].isna().sum()
# Out:
# 20411

# %%
data["price_usd_per_m2"].value_counts()
# Out:
# 2000.000000    574
# 2500.000000    447
# 1000.000000    397
# 1500.000000    391
# 1666.666667    373
#               ...
# 248.062016       1
# 2645.410256      1
# 316.205534       1
# 1617.161716      1
# 3047.486111      1
# Name: price_usd_per_m2, Length: 25567, dtype: int64

# %%
a = data[data.price_usd_per_m2 == 2000.000000][["country_name", "state_name"]]

# %%
a["state_name"].value_counts()
# Out:
# Capital Federal                 174
# Bs.As. G.B.A. Zona Norte        110
# Buenos Aires Costa Atlántica    101
# Bs.As. G.B.A. Zona Sur          100
# Bs.As. G.B.A. Zona Oeste         51
# Córdoba                          16
# Santa Fe                          9
# Buenos Aires Interior             7
# Río Negro                         3
# Chubut                            2
# Corrientes                        1
# Name: state_name, dtype: int64
